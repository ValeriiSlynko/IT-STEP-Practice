# %% [markdown]
# <a href="https://colab.research.google.com/github/ValeriiSlynko/IT-STEP-Practice/blob/master/Practice_Pandas/HmWrk2%20(data%20processing).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# підвантажуємо бібліотеки
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# завантажуємо dataset
df = pd.read_csv("https://raw.githubusercontent.com/HalyshAnton/IT-Step-Pyton-AI/main/module3/data/House_Rent_Dataset.csv", index_col="Unnamed: 0")

# %% [markdown]
# [Інформація про дані](https://www.kaggle.com/datasets/iamsouravbanerjee/house-rent-prediction-dataset)

# %% [markdown]
# Posted On - (публікація) -- Дата публікації
#
# BHK -- Кількість спалень, вітальня та кухня.
#
# Rent - (орендна плата) -- Вартість оренди будинку чи квартири.
#
# Size - (площа) -- Розмір будинку чи квартири у квадратних футах.
#
# Floor (поверх) -- Поверх, на якому розташоване житло, та загальна кількість поверхів у будинку (наприклад: перший із 2, третій із 5 тощо).
#
# Area Type - (тип площі) -- Розрахунок площі житла (загальна площа, корисна площа або площа забудови).
#
# Area Locality - (район) -- Місцезнаходження будинку чи квартири.
#
# City - (місто) -- Місто, де розташоване житло.
#
# Furnishing Status - (наявність меблів) -- Стан меблювання (повністю мебльоване, частково мебльоване або без меблів).
#
# Tenant Preferred (бажаний орендар) -- Тип орендаря, якому надає перевагу власник або агент.
#
# Bathroom - (ванна кімната) -- Кількість ванних кімнат.
#
# Point of Contact - (контактна особа) -- До кого звертатися за додатковою інформацією щодо житла.

# %%
df.head()
# Out:
#     Posted On  BHK     Rent    Size            Floor    Area Type  \
# 0  2022-05-18  2.0  10000.0  1100.0  Ground out of 2          NaN
# 1  2022-05-13  2.0  20000.0   800.0       1 out of 3   Super Area
# 2  2022-05-16  2.0  17000.0  1000.0       1 out of 3   Super Area
# 3  2022-07-04  2.0  10000.0   800.0       1 out of 2   Super Area
# 4         NaN  2.0   7500.0   850.0       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                       NaN  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4                       NaN  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0       2.0    Contact Owner
# 1       1.0              NaN
# 2       1.0    Contact Owner
# ...

# %% [markdown]
# # Завдання 1
# Виведіть інформацію про таблицю(кількість рядків та стовпчиків та типи даних). Також виведіть кількість пропущених значень по стовпчиках

# %% [markdown]
# # Завдання 2
# Виведіть гістограми для всіх числових стовпчиків

# %% [markdown]
# # Завдання 3
# Виведіть ящик з вусами для всіх числових стовпчиків. Де потрібно очистіть викиди

# %% [markdown]
# # Завдання 4
# Створіть Pipeline для обробки даних
